# %%
import pandas as pd
import os
import numpy as np
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

from collections import defaultdict
import tqdm
import random

# %%
transactions_path = f"transactions.csv"

# %%
transactions_data = pd.read_csv(transactions_path)

# %%
number_of_lines = 32109415
sample_num = 1109415
def skip_line(line):
    if line == 0:
        return False
    return random.random() > (sample_num / number_of_lines)

# %%
transactions_sampled = pd.read_csv(transactions_path, skiprows=skip_line)

# %% [markdown]
# # Label generation

# %%
positive_data = transactions_sampled[['client_id', 'material', 'chq_date']]

# %%
client_date_sales = defaultdict(lambda: defaultdict(set))

for _, row in tqdm.tqdm(positive_data.iterrows()):
    client_date_sales[row.client_id][row.chq_date].add(row.material)
# Out:
# 1110580it [02:12, 8369.74it/s]

# %%
def check_date(client, material, date):
    return material in client_date_sales[client][date]

# %%
clients = np.array(transactions_sampled.client_id.unique())
materials = np.array(transactions_sampled.material.unique())
dates = np.array(transactions_sampled.chq_date.unique())

# %%
negative_data = []

for client in tqdm.tqdm(clients):
    dates_sample = np.random.choice(dates, 4, replace=False)
    for date in dates_sample:
        materials_sample = np.random.choice(materials, 3, replace=False)
        for material in materials_sample:
            if not check_date(client, material, date):
                negative_data.append((client, material, date))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 92272/92272 [08:02<00:00, 191.04it/s]

# %%
negative_frame = pd.DataFrame(negative_data, columns=['client_id', 'material', 'chq_date'])

# %%
negative_frame.to_csv('negative.csv')
positive_data.to_csv('positive.csv')

# %% [markdown]
# # Merging

# %%
materials_enc = pd.read_csv('materials_encoded.csv').drop(columns=['Unnamed: 0'])

# %%
client_frame = pd.read_csv('clients.csv')

# %%
client_frame['gender'] = client_frame['gender'].apply(lambda x: x=='M')

# %%
client_frame['city'] = client_frame['city'].apply(lambda x: 0 if x == 'Moscow' else (1 if x =='St. Petersburg' else 2))

# %%
client_frame
# Out:
#                               client_id  gender  city  birthyear
# 0      1a47d62dddacc03fe90c15652f7ae1a4    True     2     1990.0
# 1      9cb909f701d25d548e953bff81192b56   False     2     1969.0
# 2      d5da0f5b841b4f83383202807995027a    True     2     1976.0
# 3      13ed7f16810b17b8cee6de834ac79a48   False     0     1966.0
# 4      215fe3ea7d5bf0415e5504e2a7f33551   False     2     1988.0
# ...                                 ...     ...   ...        ...
# 99990  9e7e66fc2c2dcfd8977bc0cffeff8eb5    True     2     1985.0
# 99991  e261c97d40ab839926c712b4aa6cefd8   False     1     1982.0
# 99992  678ef46f41f8c89f7e8578c9e9592e3e    True     2     1964.0
# 99993  274facf0609ceba803f5853bd2222208   False     2     1951.0
# 99994  8722f135c900a998021c965c94bc0875   False     2     1958.0
#
# [99995 rows x 4 columns]

# %%
merged_positive = positive_data.merge(materials_enc, on='material').merge(client_frame, on='client_id')

# %%
merged_negative = negative_frame.merge(materials_enc, on='material').merge(client_frame, on='client_id')

# %%
def fix_date(frame):
    dates = pd.to_datetime(frame['chq_date'])  - pd.Timestamp('2016-10-04 00:00:00')
    frame['chq_date'] = dates.dt.days
    return frame

# %%
merged_positive = fix_date(merged_positive)
merged_negative = fix_date(merged_negative)

# %%
merged_positive['label'] = 1
merged_negative['label'] = 0

# %%
merged = pd.concat([merged_positive, merged_negative])

# %%
merged
# Out:
#                                 client_id                          material  \
# 0        4d68fdddb5deaa496ce485bd51929ab1  d66c44ca2800163901f22ec5fb4f1021
# 1        4d68fdddb5deaa496ce485bd51929ab1  6278f48a43fb0a23036b3a11c92e726c
# 2        4d68fdddb5deaa496ce485bd51929ab1  5e3039a269ff005f2c76cea16c0cf783
# 3        4d68fdddb5deaa496ce485bd51929ab1  0b689fd70e79d5010e397b4c453e8460
# 4        4d68fdddb5deaa496ce485bd51929ab1  763e061fd79190b901082035761a4a83
# ...                                   ...                               ...
# 1106847  ee6b048e2aa02d49bb866e89dac444c9  9fff1f475ee1364ddaafdd2991be76dd
# 1106848  ee6b048e2aa02d49bb866e89dac444c9  8bbabf6269bb646e62e34ffbf1c2c4de
# 1106849  ee6b048e2aa02d49bb866e89dac444c9  2338ab0f346c8050d78b955c653d001e
# 1106850  ee6b048e2aa02d49bb866e89dac444c9  fcf72b8b2978f8d931761f77b3071b04
# 1106851  ee6b048e2aa02d49bb866e89dac444c9  fac8c60f2779bb2ccc1e09b24a601aa0
#
#          chq_date  hier_level_1  hier_level_2  hier_level_3  hier_level_4  \
# 0              28             0            10           241           871
# 1             316             0            27           376          1171
# 2             102             0            35           189           569
# 3              61             0            32           360          1129
# 4             305             0            35           119           430
# ...           ...           ...           ...           ...           ...
# 1106847       102             0             5            26           390
# 1106848       278             0            10           347          1371
# 1106849       278             0            15           228          1453
# 1106850       143             1            52           134           792
# 1106851       143             1            36           193             7
#
#          vendor  is_private_label  is_alco  gender  city  birthyear  label
# 0          2891                 0        0    True     1     1966.0      1
# 1          1386                 0        0    True     1     1966.0      1
# 2          2730                 0        0    True     1     1966.0      1
# 3          3825                 0        0    True     1     1966.0      1
# 4          3856                 0        0    True     1     1966.0      1
# ...         ...               ...      ...     ...   ...        ...    ...
# 1106847    3110                 0        0   False     2     2003.0      0
# 1106848    1309                 0        0   False     2     2003.0      0
# 1106849    1686                 0        0   False     2     2003.0      0
# 1106850    2396                 0        0   False     2     2003.0      0
# 1106851     473                 1        0   False     2     2003.0      0
#
# [2216916 rows x 14 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
clients_enc = LabelEncoder()
clients_enc.fit(merged.client_id)
merged['client_id'] = clients_enc.transform(merged.client_id)

# %%
mat_enc = LabelEncoder()
mat_enc.fit(merged.material)
merged['material'] = mat_enc.transform(merged.material)

# %%
merged.to_csv('merged.csv')

# %% [markdown]
# # Train-test split

# %%
train_frame = merged[merged.chq_date < 250]
eval_frame = merged[(merged.chq_date >= 250) & (merged.chq_date < 300)]
test_frame = merged[merged.chq_date >= 300]

# %%
y_train = train_frame['label'].to_numpy()
X_train = train_frame.drop(columns='label').to_numpy()
y_eval = eval_frame['label'].to_numpy()
X_eval = eval_frame.drop(columns='label').to_numpy()
y_test = test_frame['label'].to_numpy()
X_test = test_frame.drop(columns='label').to_numpy()

# %%
import xgboost

# %%
boost = xgboost.XGBClassifier(n_estimators=300, max_depth=3, learning_rate=0.1)

# %%
boost.fit(X_train, y_train, eval_set=((X_eval, y_eval),), eval_metric='auc')
# Out:
# [0]	validation_0-auc:0.65702
# [1]	validation_0-auc:0.68666
# [2]	validation_0-auc:0.68666
# [3]	validation_0-auc:0.69225
# [4]	validation_0-auc:0.69586
# [5]	validation_0-auc:0.69943
# [6]	validation_0-auc:0.70591
# [7]	validation_0-auc:0.70398
# [8]	validation_0-auc:0.70792
# [9]	validation_0-auc:0.71083
# [10]	validation_0-auc:0.71392
# [11]	validation_0-auc:0.71745
# [12]	validation_0-auc:0.72119
# [13]	validation_0-auc:0.72073
# [14]	validation_0-auc:0.72273
# [15]	validation_0-auc:0.72359
# [16]	validation_0-auc:0.72316
# [17]	validation_0-auc:0.72573
# [18]	validation_0-auc:0.72694
# [19]	validation_0-auc:0.72927
# [20]	validation_0-auc:0.73011
# [21]	validation_0-auc:0.73067
# [22]	validation_0-auc:0.73228
# [23]	validation_0-auc:0.73285
# [24]	validation_0-auc:0.73872
# [25]	validation_0-auc:0.73962
# [26]	validation_0-auc:0.74190
# [27]	validation_0-auc:0.74372
# [28]	validation_0-auc:0.74401
# [29]	validation_0-auc:0.74436
# [30]	validation_0-auc:0.74473
# [31]	validation_0-auc:0.74562
# [32]	validation_0-auc:0.74614
# [33]	validation_0-auc:0.74638
# [34]	validation_0-auc:0.74661
# [35]	validation_0-auc:0.74817
# [36]	validation_0-auc:0.74948
# [37]	validation_0-auc:0.75023
# [38]	validation_0-auc:0.75057
# [39]	validation_0-auc:0.75086
# [40]	validation_0-auc:0.75085
# [41]	validation_0-auc:0.75169
# [42]	validation_0-auc:0.75211
# [43]	validation_0-auc:0.75311
# [44]	validation_0-auc:0.75358
# [45]	validation_0-auc:0.75427
# [46]	validation_0-auc:0.75555
# [47]	validation_0-auc:0.75614
# [48]	validation_0-auc:0.75627
# [49]	validation_0-auc:0.75639
# [50]	validation_0-auc:0.75678
# [51]	validation_0-auc:0.75760
# [52]	validation_0-auc:0.75809
# [53]	validation_0-auc:0.75828
# [54]	validation_0-auc:0.75886
# [55]	validation_0-auc:0.75895
# [56]	validation_0-auc:0.75955
# [57]	validation_0-auc:0.76001
# [58]	validation_0-auc:0.76031
# [59]	validation_0-auc:0.76055
# [60]	validation_0-auc:0.76128
# [61]	validation_0-auc:0.76140
# [62]	validation_0-auc:0.76159
# [63]	validation_0-auc:0.76181
# [64]	validation_0-auc:0.76209
# [65]	validation_0-auc:0.76266
# [66]	validation_0-auc:0.76318
# [67]	validation_0-auc:0.76373
# [68]	validation_0-auc:0.76373
# [69]	validation_0-auc:0.76379
# [70]	validation_0-auc:0.76384
# [71]	validation_0-auc:0.76467
# [72]	validation_0-auc:0.76488
# [73]	validation_0-auc:0.76552
# [74]	validation_0-auc:0.76577
# [75]	validation_0-auc:0.76619
# [76]	validation_0-auc:0.76661
# [77]	validation_0-auc:0.76700
# [78]	validation_0-auc:0.76724
# [79]	validation_0-auc:0.76727
# [80]	validation_0-auc:0.76808
# [81]	validation_0-auc:0.76818
# [82]	validation_0-auc:0.76790
# [83]	validation_0-auc:0.76819
# [84]	validation_0-auc:0.76866
# [85]	validation_0-auc:0.76919
# [86]	validation_0-auc:0.76960
# [87]	validation_0-auc:0.76986
# [88]	validation_0-auc:0.77026
# [89]	validation_0-auc:0.77071
# [90]	validation_0-auc:0.77098
# [91]	validation_0-auc:0.77111
# [92]	validation_0-auc:0.77174
# [93]	validation_0-auc:0.77190
# [94]	validation_0-auc:0.77237
# [95]	validation_0-auc:0.77240
# [96]	validation_0-auc:0.77267
# [97]	validation_0-auc:0.77270
# [98]	validation_0-auc:0.77314
# [99]	validation_0-auc:0.77337
# [100]	validation_0-auc:0.77364
# [101]	validation_0-auc:0.77383
# [102]	validation_0-auc:0.77418
# [103]	validation_0-auc:0.77431
# [104]	validation_0-auc:0.77453
# [105]	validation_0-auc:0.77481
# [106]	validation_0-auc:0.77503
# [107]	validation_0-auc:0.77513
# [108]	validation_0-auc:0.77541
# [109]	validation_0-auc:0.77558
# [110]	validation_0-auc:0.77569
# [111]	validation_0-auc:0.77597
# [112]	validation_0-auc:0.77619
# [113]	validation_0-auc:0.77637
# [114]	validation_0-auc:0.77638
# [115]	validation_0-auc:0.77638
# [116]	validation_0-auc:0.77647
# [117]	validation_0-auc:0.77679
# [118]	validation_0-auc:0.77711
# [119]	validation_0-auc:0.77721
# [120]	validation_0-auc:0.77730
# [121]	validation_0-auc:0.77745
# [122]	validation_0-auc:0.77785
# [123]	validation_0-auc:0.77815
# [124]	validation_0-auc:0.77840
# [125]	validation_0-auc:0.77870
# [126]	validation_0-auc:0.77885
# [127]	validation_0-auc:0.77926
# [128]	validation_0-auc:0.77927
# [129]	validation_0-auc:0.77932
# [130]	validation_0-auc:0.77928
# [131]	validation_0-auc:0.77962
# [132]	validation_0-auc:0.78001
# [133]	validation_0-auc:0.78021
# [134]	validation_0-auc:0.78051
# [135]	validation_0-auc:0.78101
# [136]	validation_0-auc:0.78111
# [137]	validation_0-auc:0.78139
# [138]	validation_0-auc:0.78151
# [139]	validation_0-auc:0.78175
# [140]	validation_0-auc:0.78193
# [141]	validation_0-auc:0.78198
# [142]	validation_0-auc:0.78213
# [143]	validation_0-auc:0.78236
# [144]	validation_0-auc:0.78254
# [145]	validation_0-auc:0.78254
# [146]	validation_0-auc:0.78262
# [147]	validation_0-auc:0.78272
# [148]	validation_0-auc:0.78307
# [149]	validation_0-auc:0.78320
# [150]	validation_0-auc:0.78388
# [151]	validation_0-auc:0.78416
# [152]	validation_0-auc:0.78430
# [153]	validation_0-auc:0.78418
# [154]	validation_0-auc:0.78428
# [155]	validation_0-auc:0.78439
# [156]	validation_0-auc:0.78463
# [157]	validation_0-auc:0.78467
# [158]	validation_0-auc:0.78482
# [159]	validation_0-auc:0.78488
# [160]	validation_0-auc:0.78519
# [161]	validation_0-auc:0.78538
# [162]	validation_0-auc:0.78542
# [163]	validation_0-auc:0.78584
# [164]	validation_0-auc:0.78598
# [165]	validation_0-auc:0.78609
# [166]	validation_0-auc:0.78681
# [167]	validation_0-auc:0.78684
# [168]	validation_0-auc:0.78688
# [169]	validation_0-auc:0.78688
# [170]	validation_0-auc:0.78723
# [171]	validation_0-auc:0.78728
# [172]	validation_0-auc:0.78730
# [173]	validation_0-auc:0.78737
# [174]	validation_0-auc:0.78741
# [175]	validation_0-auc:0.78756
# [176]	validation_0-auc:0.78768
# [177]	validation_0-auc:0.78770
# [178]	validation_0-auc:0.78771
# [179]	validation_0-auc:0.78817
# [180]	validation_0-auc:0.78821
# [181]	validation_0-auc:0.78829
# [182]	validation_0-auc:0.78865
# [183]	validation_0-auc:0.78873
# [184]	validation_0-auc:0.78905
# [185]	validation_0-auc:0.78925
# [186]	validation_0-auc:0.78925
# [187]	validation_0-auc:0.78909
# [188]	validation_0-auc:0.78924
# [189]	validation_0-auc:0.78929
# [190]	validation_0-auc:0.78940
# [191]	validation_0-auc:0.78947
# [192]	validation_0-auc:0.78948
# [193]	validation_0-auc:0.78944
# [194]	validation_0-auc:0.78962
# [195]	validation_0-auc:0.78967
# [196]	validation_0-auc:0.78976
# [197]	validation_0-auc:0.79038
# [198]	validation_0-auc:0.79047
# [199]	validation_0-auc:0.79058
# [200]	validation_0-auc:0.79071
# [201]	validation_0-auc:0.79090
# [202]	validation_0-auc:0.79095
# [203]	validation_0-auc:0.79095
# [204]	validation_0-auc:0.79098
# [205]	validation_0-auc:0.79110
# [206]	validation_0-auc:0.79129
# [207]	validation_0-auc:0.79140
# [208]	validation_0-auc:0.79143
# [209]	validation_0-auc:0.79145
# [210]	validation_0-auc:0.79156
# [211]	validation_0-auc:0.79183
# [212]	validation_0-auc:0.79190
# [213]	validation_0-auc:0.79195
# [214]	validation_0-auc:0.79200
# [215]	validation_0-auc:0.79205
# [216]	validation_0-auc:0.79212
# [217]	validation_0-auc:0.79216
# [218]	validation_0-auc:0.79246
# [219]	validation_0-auc:0.79270
# [220]	validation_0-auc:0.79274
# [221]	validation_0-auc:0.79303
# [222]	validation_0-auc:0.79309
# [223]	validation_0-auc:0.79332
# [224]	validation_0-auc:0.79346
# [225]	validation_0-auc:0.79367
# [226]	validation_0-auc:0.79371
# [227]	validation_0-auc:0.79388
# [228]	validation_0-auc:0.79392
# [229]	validation_0-auc:0.79399
# [230]	validation_0-auc:0.79392
# [231]	validation_0-auc:0.79398
# [232]	validation_0-auc:0.79416
# [233]	validation_0-auc:0.79426
# [234]	validation_0-auc:0.79456
# [235]	validation_0-auc:0.79473
# [236]	validation_0-auc:0.79479
# [237]	validation_0-auc:0.79482
# [238]	validation_0-auc:0.79519
# [239]	validation_0-auc:0.79524
# [240]	validation_0-auc:0.79538
# [241]	validation_0-auc:0.79548
# [242]	validation_0-auc:0.79549
# [243]	validation_0-auc:0.79557
# [244]	validation_0-auc:0.79560
# [245]	validation_0-auc:0.79570
# [246]	validation_0-auc:0.79599
# [247]	validation_0-auc:0.79605
# [248]	validation_0-auc:0.79619
# [249]	validation_0-auc:0.79624
# [250]	validation_0-auc:0.79624
# [251]	validation_0-auc:0.79648
# [252]	validation_0-auc:0.79655
# [253]	validation_0-auc:0.79655
# [254]	validation_0-auc:0.79657
# [255]	validation_0-auc:0.79665
# [256]	validation_0-auc:0.79691
# [257]	validation_0-auc:0.79658
# [258]	validation_0-auc:0.79665
# [259]	validation_0-auc:0.79677
# [260]	validation_0-auc:0.79690
# [261]	validation_0-auc:0.79693
# [262]	validation_0-auc:0.79698
# [263]	validation_0-auc:0.79709
# [264]	validation_0-auc:0.79710
# [265]	validation_0-auc:0.79730
# [266]	validation_0-auc:0.79747
# [267]	validation_0-auc:0.79750
# [268]	validation_0-auc:0.79763
# [269]	validation_0-auc:0.79769
# [270]	validation_0-auc:0.79771
# [271]	validation_0-auc:0.79776
# [272]	validation_0-auc:0.79784
# [273]	validation_0-auc:0.79790
# [274]	validation_0-auc:0.79790
# [275]	validation_0-auc:0.79792
# [276]	validation_0-auc:0.79809
# [277]	validation_0-auc:0.79812
# [278]	validation_0-auc:0.79814
# [279]	validation_0-auc:0.79817
# [280]	validation_0-auc:0.79825
# [281]	validation_0-auc:0.79825
# [282]	validation_0-auc:0.79830
# [283]	validation_0-auc:0.79842
# [284]	validation_0-auc:0.79842
# [285]	validation_0-auc:0.79857
# [286]	validation_0-auc:0.79864
# [287]	validation_0-auc:0.79878
# [288]	validation_0-auc:0.79893
# [289]	validation_0-auc:0.79893
# [290]	validation_0-auc:0.79893
# [291]	validation_0-auc:0.79894
# [292]	validation_0-auc:0.79899
# [293]	validation_0-auc:0.79905
# [294]	validation_0-auc:0.79923
# [295]	validation_0-auc:0.79931
# [296]	validation_0-auc:0.79935
# [297]	validation_0-auc:0.79946
# [298]	validation_0-auc:0.79948
# [299]	validation_0-auc:0.79957
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred = boost.predict(X_test)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_pred)
# Out:
# 0.7126984780537245

# %% [markdown]
# # Hyperparameter tuning

# %%
# learning_rates = 10.0**np.random.uniform(-3, 0, size=10)
n_trees = [50, 100, 300, 500]
max_depths = [3, 5, 7, 9]

# %%
best_params = {}
best_score = 0.0
for n_tree in n_trees:
    for max_depth in max_depths:
        params = {'n_estimators': n_tree, 'max_depth': max_depth}
        boost = xgboost.XGBClassifier(learning_rate=0.1, **params)
        boost.fit(X_train, y_train)
        y_pred = boost.predict(X_eval)
        score = roc_auc_score(y_eval, y_pred)
        if score > best_score:
            best_score = score
            best_params = params
        print(f'Params: {params}, score: {score}')
# Out:
# Params: {'n_estimators': 50, 'max_depth': 3}, score: 0.6811082680981527
# Params: {'n_estimators': 50, 'max_depth': 5}, score: 0.7091009580313319
# Params: {'n_estimators': 50, 'max_depth': 7}, score: 0.7276401008914825
# Params: {'n_estimators': 50, 'max_depth': 9}, score: 0.7483135615194264
# Params: {'n_estimators': 100, 'max_depth': 3}, score: 0.6962306015082145
# Params: {'n_estimators': 100, 'max_depth': 5}, score: 0.7241781825475228
# Params: {'n_estimators': 100, 'max_depth': 7}, score: 0.7460870228901798
# Params: {'n_estimators': 100, 'max_depth': 9}, score: 0.758300371257458
# Params: {'n_estimators': 300, 'max_depth': 3}, score: 0.7195749849571162
# Params: {'n_estimators': 300, 'max_depth': 5}, score: 0.7432415717365073
# Params: {'n_estimators': 300, 'max_depth': 7}, score: 0.7611012856412722
# Params: {'n_estimators': 300, 'max_depth': 9}, score: 0.7702148019041779
# Params: {'n_estimators': 500, 'max_depth': 3}, score: 0.7265411266867305
# Params: {'n_estimators': 500, 'max_depth': 5}, score: 0.7509949526377435
# Params: {'n_estimators': 500, 'max_depth': 7}, score: 0.7669891710808956
# Params: {'n_estimators': 500, 'max_depth': 9}, score: 0.7746384943659981

# %% [markdown]
# # Money Estimation

# %%
y_pred = boost.predict(X_test)

# %%
reversed_test = test_frame.copy()

# %%
reversed_test['client_id'] = clients_enc.inverse_transform(reversed_test['client_id'])

# %%
reversed_test['material'] = mat_enc.inverse_transform(reversed_test['material'])

# %%
reversed_test['importance'] = y_pred

# %%
reversed_test
# Out:
#                                 client_id                          material  \
# 1        4d68fdddb5deaa496ce485bd51929ab1  6278f48a43fb0a23036b3a11c92e726c
# 4        4d68fdddb5deaa496ce485bd51929ab1  763e061fd79190b901082035761a4a83
# 7        4d68fdddb5deaa496ce485bd51929ab1  0d170a25e8f8c5ae206e4b801ffcd3d2
# 9        4d68fdddb5deaa496ce485bd51929ab1  61780dd011a4357cbb38d5b9433f8cf4
# 17       4d68fdddb5deaa496ce485bd51929ab1  995cadd7922027c0df05f0bf97941d77
# ...                                   ...                               ...
# 1106825  822a1ca844fc0be5e911aaa8d5196928  b863478e836bf746348b4c92ac744d30
# 1106826  822a1ca844fc0be5e911aaa8d5196928  f80511b6f9315b26b001cf523feed49d
# 1106833  30dfbb64c2809ca9b1167a6a7805c713  9708eee62a5d3395d9ea67f4ec98f91a
# 1106834  30dfbb64c2809ca9b1167a6a7805c713  9963a36b48c83b6c859692cd8603599f
# 1106836  30dfbb64c2809ca9b1167a6a7805c713  a36664b3584c4055ef6467b3cadff03c
#
#          chq_date  hier_level_1  hier_level_2  hier_level_3  hier_level_4  \
# 1             316             0            27           376          1171
# 4             305             0            35           119           430
# 7             354             0            46           122           501
# 9             354             0             8           333           739
# 17            345             0             8            67          1613
# ...           ...           ...           ...           ...           ...
# 1106825       361             1            52            87           521
# 1106826       315             0            10           289          1795
# 1106833       359             1            23           338           987
# 1106834       359             0            10           289           990
# 1106836       359             1            56           250          1340
#
#          vendor  is_private_label  is_alco  gender  city  birthyear  label  \
# 1          1386                 0        0    True     1     1966.0      1
# 4          3856                 0        0    True     1     1966.0      1
# 7          1101                 0        0    True     1     1966.0      1
# 9          1968                 0        0    True     1     1966.0      1
# 17         3356                 0        0    True     1     1966.0      1
# ...         ...               ...      ...     ...   ...        ...    ...
# 1106825    1856                 0        0   False     2     1985.0      0
# 1106826    2451                 0        0   False     2     1985.0      0
# 1106833    3911                 1        0   False     2        NaN      0
# 1106834      34                 0        0   False     2        NaN      0
# 1106836    1281                 0        0   False     2        NaN      0
#
#          importance
# 1                 1
# 4                 1
# 7                 1
# 9                 1
# 17                1
# ...             ...
# 1106825           0
# 1106826           0
# 1106833           0
# 1106834           0
# 1106836           0
#
# [382811 rows x 15 columns]

# %%
transactions_sampled
# Out:
#          Unnamed: 0                            chq_id  \
# 0                30  9645891030b4a3d0dee526c47dcbcd13
# 1               200  cc23c42be0936fb84cdac81ecb5d4ac2
# 2               209  478598ef73bb6f2f2d8e3980c92d9193
# 3               219  58b442bb93c8823fa14c3a7406c71a23
# 4               226  58b442bb93c8823fa14c3a7406c71a23
# ...             ...                               ...
# 1110575    32109249  71530873e67284bd64cd4988ef3cf396
# 1110576    32109259  dcc09c1480fd3e0419b474d0152ed696
# 1110577    32109318  b7d414fa2ea0715c81042edca1deaab1
# 1110578    32109379  5f77812e75307c05b665911839c23693
# 1110579    32109394  0c1981655041b5ae74397df5b734ed6a
#
#                                     plant    chq_date  chq_position  \
# 0        7cd86ecb09aa48c6e620b340f6a74592  2016-11-01            11
# 1        7cd86ecb09aa48c6e620b340f6a74592  2016-11-01            14
# 2        7cd86ecb09aa48c6e620b340f6a74592  2016-11-01             1
# 3        7cd86ecb09aa48c6e620b340f6a74592  2016-11-01            27
# 4        7cd86ecb09aa48c6e620b340f6a74592  2016-11-01             2
# ...                                   ...         ...           ...
# 1110575  8257a28c7042c73d88d2404f4806cbf4  2016-10-31             1
# 1110576  8257a28c7042c73d88d2404f4806cbf4  2016-10-31             1
# 1110577  46ce6c3c1e23ab2ed612a1a43ebb2929  2016-10-31            12
# 1110578  a300549b1292442df6593433d411cead  2016-10-31             3
# 1110579  e4002dc1e7deeaae4ed8e436ef1f3fbe  2016-10-31             1
#
#                                 client_id                          material  \
# 0        4d68fdddb5deaa496ce485bd51929ab1  d66c44ca2800163901f22ec5fb4f1021
# 1        260e10d8bcda8c88978d9809d7538261  f2431e06709a50ee05efc2e9ef3f41e7
# 2        439d7c61c4016ddd027a204853dfe65c  1284bfe52154a7510bb440f9ce2e54aa
# 3        3ec3be094051d958c755e0f5154c678c  c8fa3becd13b8d45156ac55ab82d93a5
# 4        3ec3be094051d958c755e0f5154c678c  f93383168e8c685f3e0d8ebb3c4ab16e
# ...                                   ...                               ...
# 1110575  25a9754c8ab90670ff8852d124939ed1  3afa2c41341548499934a52d7338f33e
# 1110576  c9487b0580dea0b1418ae6413f2fb479  f0be85f7705ffbd2e4b2cb97a054b56a
# 1110577  bf53879cd71225fc85cb8268196f590f  6278f48a43fb0a23036b3a11c92e726c
# 1110578  8bff61bf078e1836cee7122ac1ae4988  cad2b7286d60ec58918d088503b518df
# 1110579  aeca26071de38d2fbc3c93183cdf8b2e  912893f8d3dcda0676a83b6a833eac38
#
#          sales_count  sales_sum  is_promo
# 0              0.871     261.29         1
# 1              1.000      44.99         0
# 2              1.000     329.99         0
# 3              0.306     149.94         0
# 4              1.000     239.99         0
# ...              ...        ...       ...
# 1110575        1.000       6.79         0
# 1110576        1.000      54.00         1
# 1110577        0.668      42.68         1
# 1110578        0.152       7.58         0
# 1110579        1.000      79.99         0
#
# [1110580 rows x 10 columns]

# %%
merged_predicted_inverse = transactions_sampled.merge(reversed_test, on=['client_id', 'material'])

# %%
merged_predicted_inverse.label
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 212029    1
# 212030    1
# 212031    1
# 212032    0
# 212033    0
# Name: label, Length: 212034, dtype: int64

# %%
instock_frame = pd.read_csv('instock.csv').drop(columns=['Unnamed: 0'])
instock_dict = defaultdict(set)

for _, row in tqdm.tqdm(instock_frame.iterrows()):
    for i, val in enumerate(row[2:]):
        if val > 0:
            instock_dict[row[0] + row[1]].add(row.index[i + 2])
# Out:
# 23596it [01:08, 342.97it/s]

# %%
def check_in_stock(row):
    mat_id = row.plant + row.material
    if instock_dict.get(mat_id) is None:
        return True
    return row.chq_date_x in instock_dict[mat_id]

# %%
merged_predicted_inverse.apply(check_in_stock, axis=1)
# Out:
# 0          True
# 1          True
# 2         False
# 3         False
# 4          True
#           ...
# 212029    False
# 212030     True
# 212031    False
# 212032    False
# 212033    False
# Length: 212034, dtype: bool

# %%
merged_predicted_inverse[merged_predicted_inverse.chq_date_x == '2017-08-25']
# Out:
#         Unnamed: 0                            chq_id  \
# 1          8518661  65c4aa82f8c72d825bc86a1882f583f3
# 97        28256127  8c7923b99d4a67d8dbf7e2344fd30ac5
# 98        28256127  8c7923b99d4a67d8dbf7e2344fd30ac5
# 177       28245324  1197588722042a4c005d141804f9c7ab
# 373       28237052  2fcc32e86757a9fe8dce8731072cb60e
# ...            ...                               ...
# 150462    28257208  c83779055174f109c4dfa0ed233cb417
# 150463    28257227  de8d2cbf7796dce4d25a55be85eea9ed
# 150464    28257272  248c7612220f427552be48df65ac65a1
# 150465    28257277  1b743cd07f98d06cc5055fff9e61c495
# 150466    28257368  a9cb128c9332ee688336695edfaedb65
#
#                                    plant  chq_date_x  chq_position  \
# 1       0f3de8bf2672002182482b5a55464b13  2017-08-25             1
# 97      5359c847ef4975cdc646e8be8cb5621f  2017-08-25             8
# 98      5359c847ef4975cdc646e8be8cb5621f  2017-08-25             8
# 177     84f7b02a8128f5f5775611244c24b941  2017-08-25             1
# 373     85d606c4530d98879e87f1be4aa56fc2  2017-08-25             2
# ...                                  ...         ...           ...
# 150462  238d77348d954fdd455aabb09575f2d0  2017-08-25             8
# 150463  6e1acaeb838a890e6570284f73e1d00f  2017-08-25             2
# 150464  6e1acaeb838a890e6570284f73e1d00f  2017-08-25            14
# 150465  6e1acaeb838a890e6570284f73e1d00f  2017-08-25             4
# 150466  8a5dd78aadea6ffc984bda22064adb92  2017-08-25             2
#
#                                client_id                          material  \
# 1       bbfb43daf80f1e5caad1f31b5d550984  b75147feae4cf8ec07fb5f2cef855def
# 97      72ad70c18abcb8151d3098338390d029  564840544bef2c259cf7a0642ab97b2e
# 98      72ad70c18abcb8151d3098338390d029  564840544bef2c259cf7a0642ab97b2e
# 177     e147e71462765827362bbe8437f16107  b75147feae4cf8ec07fb5f2cef855def
# 373     43a8fab4b0bc01d3fc50485fa3ad0183  58f3735e298a6cff28fba744e8a5f322
# ...                                  ...                               ...
# 150462  da7fbf7514e484da3dcc46f50fce81f2  72ddaea10db500a90cb3e89376229e6e
# 150463  5b55d66c80c246a1daf8b12b3d438645  8b7b62bbea5b8975087458ddae8d041b
# 150464  0c96bb6e56c357962466d11875c94469  53a5a6521ce6021b2259cd2ffd1b9dc7
# 150465  ed3673d58d2d47c5d0269a43aa590d1c  6166da0d2cfb0bbdd7b621e4b3e95f7e
# 150466  5cd60d060d07911e98c23f7b8692c303  71457422762ef006c61375f73c9edba8
#
#         sales_count  sales_sum  is_promo  ...  hier_level_3  hier_level_4  \
# 1               1.0       3.79         0  ...           303           688
# 97              1.0      53.99         0  ...            15           847
# 98              1.0      53.99         0  ...            15           847
# 177             3.0      10.47         0  ...           303           688
# 373             4.0     288.04         0  ...            60          1922
# ...             ...        ...       ...  ...           ...           ...
# 150462          1.0      27.19         0  ...           267           966
# 150463          1.0     106.00         0  ...           172           598
# 150464          1.0      48.86         1  ...           183           360
# 150465          1.0      27.77         0  ...           213           726
# 150466          2.0      59.98         1  ...            83           448
#
#         vendor  is_private_label  is_alco  gender  city  birthyear  label  \
# 1         1381                 1        0   False     1     1987.0      1
# 97        1378                 1        0   False     1     1948.0      1
# 98        1378                 1        0   False     1     1948.0      1
# 177       1381                 1        0   False     2     1981.0      1
# 373       3845                 1        0    True     1     1958.0      1
# ...        ...               ...      ...     ...   ...        ...    ...
# 150462     207                 0        0   False     2     1976.0      1
# 150463    1524                 0        0   False     2     1990.0      1
# 150464     969                 0        0   False     2     1958.0      1
# 150465    3952                 0        0   False     2     1959.0      1
# 150466    3825                 0        0   False     2     1933.0      1
#
#         importance
# 1                1
# 97               1
# 98               1
# 177              1
# 373              1
# ...            ...
# 150462           1
# 150463           1
# 150464           1
# 150465           1
# 150466           1
#
# [2909 rows x 23 columns]

# %%
instock_frame[['plant', 'material', '2017-08-25']]
# Out:
#                                   plant                          material  \
# 0      00fdea78e677259a3e44868468f24bbf  0b689fd70e79d5010e397b4c453e8460
# 1      00fdea78e677259a3e44868468f24bbf  0de2d4c7997862a3cb3fa23409a0171e
# 2      00fdea78e677259a3e44868468f24bbf  0e2823baca6c23c591c96e7399a74ae6
# 3      00fdea78e677259a3e44868468f24bbf  0e31ad075d99fab63be09dad89580d71
# 4      00fdea78e677259a3e44868468f24bbf  119a9ea3a832472e1c163e5c1afba59e
# ...                                 ...                               ...
# 23591  ff1e1ec06b812e935f5875c40924d7fc  6278f48a43fb0a23036b3a11c92e726c
# 23592  ff1e1ec06b812e935f5875c40924d7fc  b75147feae4cf8ec07fb5f2cef855def
# 23593  ffe49cdf45d56b04b8542e6abc4f5fb6  3afa2c41341548499934a52d7338f33e
# 23594  ffe49cdf45d56b04b8542e6abc4f5fb6  6278f48a43fb0a23036b3a11c92e726c
# 23595  ffe49cdf45d56b04b8542e6abc4f5fb6  b75147feae4cf8ec07fb5f2cef855def
#
#        2017-08-25
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 23591           1
# 23592           1
# 23593           1
# 23594           0
# 23595           0
#
# [23596 rows x 3 columns]

# %%
merged_predicted_inverse
# Out:
#         Unnamed: 0                            chq_id  \
# 0             1039  f4867385149b52425628d3d2c8f92697
# 1          8518661  65c4aa82f8c72d825bc86a1882f583f3
# 2             4097  121538c8a797732395e655c7f203b9ff
# 3         27761932  747da843b92609b0c97d2fd938dee3d2
# 4            13088  7f015417f15f865bba648cbcb105fd04
# ...            ...                               ...
# 212029    30228647  98087f17234f87a16d5e84ae7e9b226d
# 212030    30228653  98087f17234f87a16d5e84ae7e9b226d
# 212031    30228669  9a6660b2b3797d87bdb1138c9c87b684
# 212032    31352112  9f61adb2a56ba76525c6d5a86dd62420
# 212033    31633625  3de2238418db8303b98e29f3c5a991f5
#
#                                    plant  chq_date_x  chq_position  \
# 0       6950aac2d7932e1f1a4c3cf6ada1316e  2016-11-01             1
# 1       0f3de8bf2672002182482b5a55464b13  2017-08-25             1
# 2       2aceac02230cdeb39aaf319ac6779462  2016-11-01             1
# 3       2aceac02230cdeb39aaf319ac6779462  2017-08-17            17
# 4       54e0f6e4ee558d9346d379b4ca2a25a0  2016-11-01             1
# ...                                  ...         ...           ...
# 212029  8a5dd78aadea6ffc984bda22064adb92  2017-10-03             7
# 212030  8a5dd78aadea6ffc984bda22064adb92  2017-10-03            12
# 212031  8a5dd78aadea6ffc984bda22064adb92  2017-10-03             4
# 212032  45226bae7da31547fbdca1c62d24a8dd  2016-10-20             4
# 212033  a9b2b0ce7799c4de9c7a3aed9ebeddeb  2016-10-25            39
#
#                                client_id                          material  \
# 0       bbfb43daf80f1e5caad1f31b5d550984  b75147feae4cf8ec07fb5f2cef855def
# 1       bbfb43daf80f1e5caad1f31b5d550984  b75147feae4cf8ec07fb5f2cef855def
# 2       1d64234079fc2d5635b00aa801cf6629  2f588cc938971a6efdfe762392e31d3c
# 3       1d64234079fc2d5635b00aa801cf6629  2f588cc938971a6efdfe762392e31d3c
# 4       faa471316a5b6976273c59decfd26c76  3afa2c41341548499934a52d7338f33e
# ...                                  ...                               ...
# 212029  9da09afdb6607191389d5f30274710cd  e6b6bb5e0332799839019f6e132c1017
# 212030  9da09afdb6607191389d5f30274710cd  6278f48a43fb0a23036b3a11c92e726c
# 212031  9810a8dcc0d728e60af3e86177fae709  d5e56b631814d9553852715bc5ceb8e3
# 212032  b09b1c7e1eeb6379e102ede0e606ee3b  d688ebcbd7c01ae0eaf214c9a82c1b88
# 212033  9da2547ba7900a4e2ef80227325a0485  7795a38bbd53553020d4e2fbab52b312
#
#         sales_count  sales_sum  is_promo  ...  hier_level_3  hier_level_4  \
# 0             1.000       3.49         0  ...           303           688
# 1             1.000       3.79         0  ...           303           688
# 2             2.000     257.62         0  ...            61           710
# 3             2.000     197.98         1  ...            61           710
# 4             2.000      13.58         0  ...           303           688
# ...             ...        ...       ...  ...           ...           ...
# 212029        1.000      98.89         0  ...           170           614
# 212030        1.124      63.94         0  ...           376          1171
# 212031        1.000      24.99         1  ...            83          1185
# 212032        1.000      24.19         0  ...           350          1804
# 212033        2.000      18.78         0  ...           386           176
#
#         vendor  is_private_label  is_alco  gender  city  birthyear  label  \
# 0         1381                 1        0   False     1     1987.0      1
# 1         1381                 1        0   False     1     1987.0      1
# 2         1819                 0        0   False     2     1963.0      1
# 3         1819                 0        0   False     2     1963.0      1
# 4         1381                 1        0   False     2     1991.0      1
# ...        ...               ...      ...     ...   ...        ...    ...
# 212029    3077                 0        0   False     2     1952.0      1
# 212030    1386                 0        0   False     2     1952.0      1
# 212031    1221                 0        0   False     2     1948.0      1
# 212032     930                 0        0   False     2        NaN      0
# 212033     389                 1        0   False     1     1972.0      0
#
#         importance
# 0                1
# 1                1
# 2                0
# 3                0
# 4                1
# ...            ...
# 212029           1
# 212030           1
# 212031           1
# 212032           1
# 212033           1
#
# [212034 rows x 23 columns]

# %%
instock_frame[(instock_frame.plant==plant) | (instock_frame[day] == 0)].material.unique()

# %%
day = '2017-09-01'

plant = '2aceac02230cdeb39aaf319ac6779462'


clients = merged_predicted_inverse[(merged_predicted_inverse['plant'] == plant) & (merged_predicted_inverse['chq_date_x'] != day)].client_id.unique()

absent_items = instock_frame[(instock_frame.plant==plant) | (instock_frame[day] == 0)].material.unique()

points = []
for item in absent_items:
    for client in clients:
        points.append((client, item, day))

# %%
len(clients), len(absent_items)
# Out:
# (199, 2118)

# %%
negative_frame = pd.DataFrame(points, columns=['client_id', 'material', 'chq_date'])

# %%
trial_points = negative_frame.merge(materials_enc, on='material').merge(client_frame, on='client_id')
trail_points = fix_date(trial_points)
trail_points['client_id'] = clients_enc.transform(trail_points.client_id)
trail_points['material'] = mat_enc.transform(trail_points.material)

# %%
trail_points
# Out:
#         client_id  material  chq_date  hier_level_1  hier_level_2  \
# 0           10536      3416       332             0            13
# 1           10536      3472       332             0            49
# 2           10536      4325       332             0            26
# 3           10536      4453       332             0            13
# 4           10536      6723       332             0            35
# ...           ...       ...       ...           ...           ...
# 421278      87455     40842       332             0            21
# 421279      87455     42976       332             0            28
# 421280      87455     43109       332             0            32
# 421281      87455     43953       332             0            28
# 421282      87455     56218       332             0            28
#
#         hier_level_3  hier_level_4  vendor  is_private_label  is_alco  gender  \
# 0                 81             3    3534                 0        1   False
# 1                313           125    2674                 0        0   False
# 2                 93          1894    3825                 0        0   False
# 3                 81             3    2715                 0        1   False
# 4                366          1861    1999                 0        0   False
# ...              ...           ...     ...               ...      ...     ...
# 421278            15           847    3119                 0        0   False
# 421279           267           966    2594                 0        0   False
# 421280           219          1332     922                 0        0   False
# 421281           267          1668     436                 0        0   False
# 421282            66           791      93                 0        0   False
#
#         city  birthyear
# 0          2     1963.0
# 1          2     1963.0
# 2          2     1963.0
# 3          2     1963.0
# 4          2     1963.0
# ...      ...        ...
# 421278     2     1956.0
# 421279     2     1956.0
# 421280     2     1956.0
# 421281     2     1956.0
# 421282     2     1956.0
#
# [421283 rows x 13 columns]

# %%
X = trial_points.to_numpy()

# %%
y_pred_absent = boost.predict(X)

# %%
trail_points['importance'] = y_pred_absent

# %%
wanted = trail_points[trail_points.importance == 1]

# %%
wanted_counts = wanted.groupby('client_id').count()['material']
wanted_counts[wanted_counts > 1500].index
# Out:
# Int64Index([  505,  1495,  2251,  2630,  6439,  6703, 15175, 16646, 19442,
#             24429, 24879, 30000, 32258, 34897, 35455, 35764, 37433, 39238,
#             41152, 43598, 46835, 47671, 50869, 53018, 58566, 63377, 71159,
#             73639, 73950, 75273, 77192, 81848, 84567, 87570, 88185, 90505,
#             90564, 90976, 91966],
#            dtype='int64', name='client_id')

# %%
missed_guys = clients_enc.inverse_transform(wanted_counts[wanted_counts > 1500].index)

# %%
missed_guys = np.array(['01742ebdb1ceea185feceadcd8adcee7',
       '0438348c515c19d933831bec1cc1d472',
       '0643672bc38f396c63eade84873089d9',
       '0747aaa37d462a90b4facb6212776108',
       '1214110e2a682607c15ee0ff419514d7',
       '12c024a0da33be50f48d90b94249d6fa',
       '2a2554ac431c95d6b98823322bac9ab1',
       '2e3eb384999442dd199fdf3a4c0d9463',
       '364173053bc689ce9f066ff3b3c63619',
       '443fc94f1f1c1ecabfe50a3bdce2bfc7',
       '458782935990b03ec7ddf27ffc7ad95a',
       '53cf6ba19ddbe0609da034b13b0e8030',
       '5a2c907344800f6573df7229b6847cf3',
       '6175f0aeb5b3a5b2054b16f7e2d6db1e',
       '62eb27f5ebba590131416c20c266ef8a',
       '63d4c707a9d5a6264c0f19f83b057f6d',
       '6843d220891dfb09767a8d7e719288d5',
       '6d565aab852aa329dcf5c1eb9d46d8eb',
       '72c3b4ac505b2087953126994006a3d1',
       '79927bfe23610509d2a4731a28c1c966',
       '8297e06b9d0762ffeaebe4f750a8471f',
       '84f33d48a91b8b82051233d566eb61f9',
       '8dd1569ab4ccefb62edb9ad92c1cd352',
       '93ac385fb056e2d18255885d6fc2cd27',
       'a325303f74c6699dac446c786ab8d256',
       'b070c97c5cff17965e958781fec5664b',
       'c61f8b89cbd5110d863739e1ea20e63e',
       'ccc52dc26bc23320079a63017f7d9b6c',
       'cd8e7c9d39a8b0871834f9724578547d',
       'd136a031b07f474a877be41f353dc579',
       'd6612b8b11866d713b4adb2570e8bb2b',
       'e30acbe28af7cd241123976e55f8cea2',
       'eab24fef6bb1aca7059f5531915f64a6',
       'f2f1e1acef187e4e021cfdfb9c698a85',
       'f4aace0295afc7a5d9ded9420905c439',
       'fb1d5aa2e4fe656fc8dcb2f5d5e47f1f',
       'fb4c2f7aaf76fa6fb113ad8cf0365581',
       'fc772273845707de231d69e5e00048ad',
       'ff30a1b016016cb2c89c5826dcb56f89'])

# %%
mean_loss = 0.0
for guy in tqdm.tqdm(missed_guys):
    mean_loss += transactions_data[transactions_data.client_id == guy].groupby('chq_id').sum().mean()['sales_sum']
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 39/39 [01:11<00:00,  1.83s/it]

# %%
mean_loss
# Out:
# 55593.04334909091

# %%
monthly = mean_loss * 30
monthly
# Out:
# 1667791.3004727273

# %%
transactions_data[transactions_data.plant == '6bcf53c2bdbee891ffaca1e612b0076c'].sales_sum.sum() / 12
# Out:
# 2443294.27

# %%
transactions_data.plant.unique()[:20]
# Out:
# array(['7cd86ecb09aa48c6e620b340f6a74592',
#        '6950aac2d7932e1f1a4c3cf6ada1316e',
#        'b6fb522815d06fed82b0140be4c74680',
#        '857778a20b9a41d4ca0d687a36e4bfa8',
#        'd9f5e405a7f74ed652a8f0b31a87f636',
#        'ed0a75eeb69b34ddc14beed2678bee12',
#        '0e0b24fc303d2b384be5a2464654a5d2',
#        'c90070ff096dd6858022784617b2f383',
#        '8ae502a489e46e16512581742d93db9c',
#        '99cb58d2d19256c97a9055c0675bcb27',
#        '0bb0666df4640d65ed353b3bfca34d6e',
#        '2d0974b2436345d99f7152c3fc44a609',
#        '028f7ee9eb0c0994a8ba1e60bcffd09e',
#        'b2c3b75b24f611bde67921d19c8dffcd',
#        '7792dd2aad4d5547e11d9317b03c32c6',
#        '2aceac02230cdeb39aaf319ac6779462',
#        'b323b8172b421577bf8e70d411d79a50',
#        'c76b3d3ab1522b66814253d642932e9e',
#        '021ed42efda232c8b396e590360a5b89',
#        '6bcf53c2bdbee891ffaca1e612b0076c'], dtype=object)
